# %% [markdown]
# # References
#   - **Paper Name:** CLIP-SCGI: Synthesized Caption-Guided Inversion for Person Re-Identification
#   - **Authors:** Qianru Han, Xinwei He, Zhi Liu, Sannyuya Liu, Ying Zhang, Jinhai Xiang
#   - **Paper Link:** https://arxiv.org/abs/2410.09382

# %% [markdown]
# ----
# ----

# %% [markdown]
# ## **Abstract  CLIP-SCGI: Synthesized Caption-Guided Inversion for Person Re-Identification**
#
# This paper introduces **CLIP-SCGI**, a method that improves **Person Re-Identification (ReID)** by using **caption-guided learning** in large **vision-language models** like CLIP. Below is a **simplified breakdown** of the abstract:
#
# ---

# %% [markdown]
# ### ** Problem Statement**
# - **Person ReID** is used to identify people in images taken by different cameras.
# - **CLIP** (a powerful vision-language model) has improved ReID, but it lacks **clear textual descriptions** for images.
# - Existing **ReID models** use **implicit text embeddings** that require **complex and inefficient training**.
# - **Solution needed**: A way to **generate meaningful text descriptions** for images and use them to improve ReID.
#
# ---

# %% [markdown]
# ### ** Key Idea (Proposed Solution)**
# - Use **image captioning models** (like **LLAVA**) to **automatically generate** text descriptions (**pseudo captions**) for ReID images.
# - These captions include important **visual attributes** like **gender, clothing, and age**.
# - This converts the training data from **image-only (uni-modal)** to **image + text (bi-modal)** for better **feature learning**.
#
# ---

# %% [markdown]
# ### ** How CLIP-SCGI Works**
# 1. **Caption Generation**:
#    - A **captioning model** generates **pseudo captions** (e.g., A young man in a red jacket and black pants).
#    - These captions describe **key identity-relevant attributes** for better ReID.
#
# 2. **Caption-Guided Inversion Module**:
#    - Converts **important visual features** into **pseudo-word tokens** based on the generated captions.
#    - Helps the model focus on the **most relevant image parts**.
#
# 3. **Cross-Modal Fusion Module**:
#    - Combines **image and text features** to make training **more effective**.
#    - Ensures that the **visual encoder learns more discriminative and robust features**.
#
# ---

# %% [markdown]
# ### ** Results & Impact**
# - **Significant improvement** over the **state-of-the-art** ReID models.
# - **Better feature extraction** and **region focus** lead to **higher accuracy** in person matching.
# - **More efficient learning** by using captions to **guide the visual encoder**.
#
# ---

# %% [markdown]
# ### ** Key Takeaways**
#  **CLIP-SCGI improves ReID** by **leveraging captions** for **better training**.
#  **It enhances CLIP** by introducing **bi-modal learning** (image + text).
#  **The model becomes more accurate** by using captions to **guide attention** to important areas.
#  **Outperforms existing methods** in **multiple ReID datasets**.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ** Introduction  CLIP-SCGI: Synthesized Caption-Guided Inversion for Person Re-Identification**
#
# This section introduces **CLIP-SCGI**, a novel method for **Person Re-Identification (ReID)** that leverages **generated text captions** to improve training. Below is a **detailed breakdown** covering **every key point**.
#
# ---

# %% [markdown]
# ### ** What is Person Re-Identification (ReID)?**
# - **Person Re-Identification (ReID)** is a computer vision task that focuses on recognizing the **same person** across different camera views.
# - It plays a **critical role in intelligent surveillance** for **public safety and security**.
# - It is usually formulated as a **retrieval task**:
#   - **Input (Query):** An image of a person (probe).
#   - **Goal:** Find the **matching image(s)** in a set of **gallery images**.
#
# ---

# %% [markdown]
# ### ** Challenges in Person ReID**
# ReID is **highly challenging** due to various factors:
# 1. **Changes in lighting**  Different environments and times affect how a person appears.
# 2. **Pose variations**  People look different in different positions and angles.
# 3. **Occlusions**  Objects or other people may **partially block** the person.
# 4. **Small datasets**  Existing datasets contain **limited images**, leading to **overfitting** in models.
#
# ---

# %% [markdown]
# ### ** Existing Solutions and Their Limitations**

# %% [markdown]
# #### **1 Feature-Based Learning**
#
# - **Global feature methods**  Extract entire persons appearance to match across images [5,6].
# - **Local feature methods**  Focus on body parts to improve identity matching [7,8].

# %% [markdown]
# #### **2 Loss-Based Learning**
# - **Pairwise loss**  Reduces the **distance** between correct matches while maximizing the difference with wrong matches [9].
# - **Triplet loss**  Ensures the **query image is closer to the correct match** than incorrect ones [10].

# %% [markdown]
# #### **3 CLIP for ReID (CLIP-ReID)**
# - **CLIP** (Contrastive Language-Image Pretraining) is a **powerful model** trained on **400 million** image-text pairs [11].
# - **CLIP-ReID** [12] adapted CLIP for ReID and **showed promising results**, but had major issues:
#   - **ReID datasets lack image-text pairs**, so **learnable text embeddings** were used instead.
#   - Required **a complex two-stage training process**:
#     - **First, train the image encoder** while keeping the text encoder frozen.
#     - **Then, train the text encoder** while freezing the image encoder.
#   - **Major Problems** of CLIP-ReID:
#     - **Implicit text embeddings lack clear meaning**, making training **less effective**.
#     - **Training is inefficient** due to the **separate optimization of image and text encoders**.
#
# ---

# %% [markdown]
# ### ** Proposed Solution: CLIP-SCGI**
# CLIP-SCGI introduces **Synthesized Caption-Guided Inversion** to **overcome CLIP-ReIDs limitations**.

# %% [markdown]
# #### **How CLIP-SCGI Works**
# 1. **Synthetic Caption Generation**:
#    - Uses a **pretrained image captioning model (LLAVA) [13]** to generate **detailed textual descriptions** for each image.
#    - Captions describe **important attributes** like **clothing, gender, and accessories** (e.g., *"A woman wearing a red dress and black shoes"*).
#    - This makes **training more effective** by providing **clear semantic guidance**.
#
# 2. **Caption-Guided Inversion**:
#    - Converts **important visual features** into **pseudo-word tokens** (S\*) that match the generated captions.
#    - The model learns **key identity-specific details** and **focuses on relevant features**.
#
# 3. **Image-Text Fusion for Representation Learning**:
#    - Image and text embeddings are **combined** to improve feature learning.
#    - The model **aligns visual features** with **semantic information**, ensuring **better generalization**.
#
# ---

# %% [markdown]
# ### ** Advantages of CLIP-SCGI**
#  **Stronger Feature Learning**
# - Traditional ReID models **overfit to clothing** (e.g., just recognizing color), while CLIP-SCGI **learns more robust identity features**.
#
#  **No Need for Expensive Human Annotations**
# - Captions are **automatically generated**, so **no manual labeling** is required.
#
#  **Better Generalization**
# - The model **leverages shared attributes** (e.g., clothing type, accessories) instead of memorizing **exact pixels**.
#
#  **Efficient Training (One-Stage Learning)**
# - **Unlike CLIP-ReID**, which required **two-stage training**, CLIP-SCGI **trains everything together**, making it **simpler and faster**.
#
#  **Does Not Increase Inference Time**
# - **Captions are only used during training**.
# - Once training is complete, the **text guidance is no longer needed**, ensuring **fast inference speeds**.
#
#  **Achieves State-of-the-Art Performance**
# - CLIP-SCGI **outperforms all previous methods** on ReID datasets.
# - On **MSMT17**, it achieves **88.2% mAP**, setting a **new record**.
#
# ---

# %% [markdown]
# ### ** Key Takeaways**
# 1. **CLIP-SCGI improves upon CLIP-ReID** by using **generated captions** instead of **implicit text embeddings**.
# 2. **It introduces caption-guided inversion**, which **maps visual details to pseudo-word tokens**, improving training.
# 3. **The model fuses image and text embeddings** to **enhance feature learning**.
# 4. **It requires no additional manual annotation** and **does not slow down inference**.
# 5. **It significantly improves person ReID performance**, especially in **challenging datasets like MSMT17**.
#
# ---

# %% [markdown]
# #### ** Figure 1 Explanation: CLIP-ReID vs. CLIP-SCGI**
# | **Method** | **How It Works** | **Problems** |
# |------------|----------------|-------------|
# | **(a) CLIP-ReID** | Uses **learnable text embeddings** to represent images. | Text embeddings **lack clear meaning** and require a **complicated pretraining** process. |
# | **(b) CLIP-SCGI (Proposed)** | Uses **generated captions** to directly guide image feature learning. | **Simplifies training** and **improves accuracy** by fusing **text and image embeddings**. |
#
# ---

# %% [markdown]
# ### ** Summary of Contributions**
# 1. **Introduces a simple but effective learning scheme** that uses **synthesized captions** for better representation learning.
# 2. **Proposes a framework based on CLIP** that effectively **fuses visual and semantic features** for ReID.
# 3. **Achieves state-of-the-art results** on multiple ReID datasets, proving its effectiveness.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ** Related Work  CLIP-SCGI: Synthesized Caption-Guided Inversion for Person Re-Identification**
#
# This section reviews previous **Person ReID methods** and how **CLIP-SCGI improves upon them**. Below is a **detailed breakdown** covering **every key point**.
#
# ---

# %% [markdown]
# ### ** A. Person Re-Identification (ReID)**
# - **ReID is a crucial task** in computer vision, primarily used for **surveillance and security applications**.
# - Traditional methods focus on:
#   1. **Feature Learning:** Extracting discriminative features using CNN-based methods [16, 17].
#   2. **Metric Optimization:** Using loss functions to compare image similarities [18, 19, 20].

# %% [markdown]
# #### ** Problems with Traditional ReID Models**
#  **Overfitting to Irrelevant Features**
# - Many CNN-based approaches **struggle with generalization** and focus on **non-discriminative regions** (e.g., background noise).
#
#  **Limited Feature Representation**
# - Some methods use **global features** (whole image) or **local features** (body parts) but fail to **combine both effectively**.
#
#  **Lack of Multi-Modal Information**
# - Most **existing models** only use **visual data** (image pixels), missing **semantic details** that could improve recognition.
#
# ---

# %% [markdown]
# #### ** Transformer-Based Approaches in ReID**
# With the **rise of Transformers**, new **self-attention-based** architectures significantly improved ReID performance [22, 23, 24, 25].
#
#  **TransReID**: Uses **pure Transformers** instead of CNNs, achieving better performance on **large-scale datasets**.
#  **AAformer**: Introduces **automatic alignment of body regions**, improving ReIDs **ability to focus on relevant parts**.
#
#  **However, these approaches still have major issues:**
# -  **They struggle with occlusions** (background objects interfering with the models attention).
# -  **They rely solely on visual features**, **ignoring language-based information** that could improve performance.
#
# ---

# %% [markdown]
# ### ** B. Vision-Language Learning for ReID**
# Recently, **Vision-Language Models (VLMs)** have been introduced to **enhance visual feature learning** by leveraging **text descriptions**.
#
# #### ** CLIP for Vision-Language Learning**
# - **CLIP (Contrastive Language-Image Pretraining)** [11] is trained on **400 million** image-text pairs, achieving **state-of-the-art results** in many tasks.
# - **CLIP-ReID** [12] was the **first** method to apply **CLIP** to **ReID**, but it had key limitations:
#   -  **It only optimized image encoders**, **not fully utilizing textual information**.
#   -  **Implicit prompts were used**, leading to **less meaningful representations**.
#
# #### ** Existing Vision-Language Models**
# - **Large Vision-Language Models (LLMs)** such as **LLaVA** [13] integrate **language models (LLMs)** with **visual encoders** to improve cross-modal learning.
# - However, most methods rely on **large-scale datasets**, which **limits their adaptability to ReID**.
#
#  **CLIP-ReID vs. CLIP-SCGI**
# - **CLIP-ReID**: Uses **learnable text embeddings** but **fails to extract meaningful semantic attributes**.
# - **CLIP-SCGI (Proposed)**: Uses **explicit captions** to guide **better feature extraction**, ensuring **higher accuracy**.
#
#  **How CLIP-SCGI Improves Vision-Language Learning**
#  **Instead of relying only on image features, CLIP-SCGI uses synthesized captions** to capture identity details.
#  **Introduces a new "text filtering" technique** to improve caption accuracy and eliminate errors.
#  **Leverages modal fusion** to combine **image and text** for **more robust learning**.
#
# ---

# %% [markdown]
# ### ** C. Representing an Image as a Single Word**
# One challenge in **image-based person ReID** is how to **convert complex visual information into a compact text representation**.
#
# #### ** Textual Inversion**
# - **Textual inversion** was first introduced to **generate personalized text-to-image models** [14].
# - It works by **learning pseudo-words** that represent **unique features** of an image in the **text embedding space**.
# - This technique has been successfully used in:
#   - **Image generation** [15, 33].
#   - **Zero-shot image retrieval** [26].
#
# #### ** How CLIP-SCGI Uses Textual Inversion**
#  **Instead of just using captions, CLIP-SCGI generates "pseudo-words" (S*)** that summarize important identity details.
#  These **pseudo-words are embedded into text prompts** like:
#   -  *A photo of [S*] person*
#  The model **uses this pseudo-word to guide feature learning**, ensuring it **captures only identity-relevant details**.
#
#  **Benefits of Textual Inversion for ReID**
#  **Eliminates background distractions** (focuses only on the person).
#  **Improves cross-modal fusion** by **aligning text and image features**.
#  **Increases ReID accuracy** by **making identity features more distinct**.
#
# ---

# %% [markdown]
# ### ** Figure 2: Caption Generation Results**
# This figure shows **how CLIP-SCGI generates captions** for the **Market-1501** and **MSMT17** datasets.
#
# #### ** How Caption Generation Works**
#
# 1 **Market-1501 Captions (Row 1)**
#    - The model generates **detailed descriptions** (e.g., *"A young man in a red shirt and blue jeans, carrying a backpack"*).
# 2 **MSMT17 Captions (Row 2)**
#    - The captions include **more complex descriptions** (e.g., *"A 20-year-old man in a blue jacket and red backpack"*).
#
#  **Key Takeaways from Figure 2**
#  **Captions contain rich semantic details** (clothing, accessories, age, etc.).
#  **This helps the model focus on identity-specific details**, instead of relying on **simple color or texture cues**.
#  **By converting images into structured text descriptions, CLIP-SCGI improves feature learning.**
#
# ---

# %% [markdown]
# ### ** Key Takeaways from the Related Work Section**
#
# 1 **Traditional CNN and Transformer-based models struggle** with occlusions, irrelevant background, and feature overfitting.
# 2 **CLIP-ReID introduced vision-language learning** but failed to **fully utilize text descriptions**.
# 3 **CLIP-SCGI improves upon CLIP-ReID** by using **explicit captions** instead of learnable text embeddings.
# 4 **Textual inversion is used to map visual details into pseudo-word tokens (S*)**, helping the model focus on identity-relevant features.
# 5 **Caption generation enhances training** by converting images into **text descriptions**, allowing the model to **better understand identity features**.
# 6 **CLIP-SCGI introduces a new text filtering method** to remove caption errors and improve learning accuracy.
#
# ---

# %% [markdown]
# ### ** Summary: Why CLIP-SCGI is Better**
# | **Method** | **What it Does** | **Problems** | **CLIP-SCGIs Improvement** |
# |------------|----------------|-------------|------------------|
# | **CNN-Based ReID** | Uses deep learning to extract image features | Overfits to clothing, struggles with occlusions | Uses **captions to guide feature extraction** |
# | **Transformer-Based ReID** | Uses attention mechanisms for feature learning | Still **relies only on image features**, ignores semantic info | Uses **vision-language fusion** to extract **better identity details** |
# | **CLIP-ReID** | Uses CLIP model but with **implicit text embeddings** | **Does not fully utilize captions**, requires **two-stage training** | Uses **explicit captions**, **one-stage training**, and **text filtering** |
# | **CLIP-SCGI (Proposed)** | Uses **Synthesized Caption-Guided Inversion** |  **Fuses image & text**  **Learns better representations**  **No extra inference cost** |  **State-of-the-art accuracy**  **Handles occlusions**  **Improves generalization** |
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ** Method  CLIP-SCGI: Synthesized Caption-Guided Inversion for Person Re-Identification**
#
# This section **explains how CLIP-SCGI works** by utilizing **image-text pairs**, **caption-guided inversion**, and **multi-modal fusion** to improve **ReID performance**. Below is a **detailed breakdown** covering **every key step**.
#
# ---

# %% [markdown]
# ### ** Overview of CLIP-SCGI Framework**
# - **CLIP-SCGI** improves ReID by **combining images with synthesized captions** to guide feature learning.
# - **Fig. 3** provides an **overview** of the framework, showing **how captions and images are processed together**.
# - **Three key components**:
#   1 **CLIP model**  Encodes both **images and text** into a shared feature space.
#   2 **Caption-Guided Inversion (CGI) module**  Converts images into **pseudo-words** guided by captions.
#   3 **Contextual Feature Fusion (CFF) module**  Merges **image and text features** for better representation learning.
#
# ---

# %% [markdown]
# ### ** A. Synthesized Caption Generation**
# #### ** Challenge: No Text in ReID Datasets**
# - **Existing ReID datasets only contain images** (no text annotations).
# - **Manual text annotation** is **expensive and time-consuming**.
#
# #### ** Solution: Using Pretrained Vision-Language Models**
# - **CLIP-SCGI automatically generates captions** for ReID datasets using **LLAVA (Large Language and Vision Assistant)** [13].
# - **LLAVA extracts important details** (e.g., **clothes, accessories, age, gender**) from images.
#
# #### ** Caption Generation Process**
#
# 1 **Each image is fed into LLAVA** to generate a caption.
# 2 **Captions describe the persons key attributes** (e.g., clothing, accessories, hair, glasses).
# 3 **Captions follow a fixed template** for consistency:
#
#   ![image.png](data:image/png;base64,...)
#
# 4 **These captions are stored offline** to create a **bi-modal dataset (image + text)** for training.
#
#  **Why This Works?**
#  **Captions provide semantic supervision**, helping the model **understand identity-specific details**.
#  **Combining images + text improves feature learning**, making the model **more discriminative**.
#
# ---

# %% [markdown]
# ### ** B. CLIP-SCGI Framework**
# **Fig. 3** shows the full **CLIP-SCGI model**, which consists of **three main components**:

# %% [markdown]
# #### **1 CLIP: Image & Text Encoding**
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **2 Caption-Guided Inversion (CGI) Module**
#
#   ![image.png](data:image/png;base64,...)
#
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **3 Contextual Feature Fusion (CFF) Module**
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ** C. Optimization & Training**
# CLIP-SCGI is trained using a **combination of three loss functions**:
#
#   ![image.png](data:image/png;base64,...)
#
#
#   ![image.png](data:image/png;base64,...)
#
#
#   ![image.png](data:image/png;base64,...)
#
#
#  Why This Works?
#
#  Improves feature separability between different identities.
#
#  Ensures image-text alignment, making the model more robust.

# %% [markdown]
# ### ** Key Takeaways from the Method Section**
# 1 **CLIP-SCGI transforms ReID datasets from image-only to image + text using LLAVA-generated captions.**
# 2 **Caption-Guided Inversion (CGI) converts images into "pseudo-words"** for better feature learning.
# 3 **Contextual Feature Fusion (CFF) merges image + text embeddings**, ensuring **better alignment**.
# 4 **Contrastive loss ensures text and image features match**, improving **discriminative power**.
# 5 **The model can drop the captioning branch after training**, making it **efficient during inference**.

# %% [markdown]
# ## IV. EXPERIMENT

# %% [markdown]
# ### ** Summary of Experiment Setup for CLIP-SCGI**
# This section **explains the datasets, evaluation protocols, and implementation details** used in **CLIP-SCGI experiments**. Below is a structured summary **covering all key points** in simple terms.
#
# ---

# %% [markdown]
# #### ** A. Experiment Setup**

# %% [markdown]
# ##### **1 Datasets and Evaluation Protocols**
# CLIP-SCGI is **evaluated on four standard person re-identification (ReID) datasets**:
# - **Market-1501**
# - **MSMT17**
# - **DukeMTMC-reID**
# - **Occluded-Duke**
#
# These datasets **contain images of people from different cameras**, and the **goal** is to correctly **match** the same person across different camera views.
#
#  **Key Metrics for Evaluation:**
# 1 **Rank-1 Accuracy (R1):** Measures if the correct match appears in the **top-1 result**.
# 2 **Mean Average Precision (mAP):** Evaluates the **overall ranking quality**, considering multiple correct matches.
#
# ---

# %% [markdown]
# ##### ** Dataset Details**
# ###### ** Market-1501**
# -  **Large-scale dataset** with **32,668 images** from **six cameras**.
# -  **1,501 identities** labeled with bounding boxes.
# -  **Split**:
#   - **Training**: 12,936 images
#   - **Testing**: 19,732 images
#
# ###### ** MSMT17**
# -  **Largest dataset** with **126,441 images** from **15 cameras**.
# -  **4,101 identities** captured in **real-world conditions**.
# -  **Split**:
#   - **Training**: 32,621 images
#   - **Query**: 11,659 images
#   - **Gallery**: 82,161 images
#
# ###### ** DukeMTMC-reID**
# -  **High-resolution dataset** with **36,411 images** from **8 cameras**.
# -  **1,812 identities** with **challenging lighting & poses**.
# -  **Split**:
#   - **Training**: 16,522 images
#   - **Query**: 2,228 images
#   - **Gallery**: 17,661 images
#
# ###### ** Occluded-Duke**
# -  **Subset of DukeMTMC-reID** with **occluded (partially hidden) people**.
# -  **1,812 identities** but with **10,056 occlusion annotations**.
# -  **Split**:
#   - **Training**: 16,522 images
#   - **Query**: 2,228 images
#   - **Gallery**: 17,661 images
#
#  **Why These Datasets?**
#  **Diverse conditions** (occlusions, lighting changes, background variations).
#  **Used in previous ReID research**, allowing for **fair comparison**.
#
# ---

# %% [markdown]
# ##### **2 Implementation Details**

# %% [markdown]
# ###### ** Model Architecture**
# - **CLIP-SCGI uses the CLIP model** as a **pretrained backbone**.
# - **Two different image encoders**:
#   - **ResNet-50 (CNN-based)**
#   - **ViT-B/16 (Transformer-based)**
# - **Text encoder:** CLIPs text transformer with **max input length of 77 tokens**.

# %% [markdown]
# ###### ** Data Processing & Augmentation**
# - **All images are resized** to **256  128 pixels**.
# - **Data augmentation**:
#    **Random flipping**
#    **Padding & cropping**
#   ✅ **Random erasing** (to simulate occlusions)

# %% [markdown]
# ###### **📌 Training Details**
# - **Batch size**: 64 (**4 images per identity**).
# - **Optimizer**: Adam.
# - **Learning rate**:
#   - **5 × 10⁻⁶** for pretrained CLIP modules.
#   - **5 × 10⁻⁵** for randomly initialized layers.
# - **Training schedule**:
#   - **10-epoch warm-up phase**: Learning rate **gradually increases** from **5 × 10⁻⁷** to **5 × 10⁻⁶**.
#   - **CNN-based model (ResNet-50)**:
#     - **120 epochs total**
#     - Learning rate **decayed at epoch 40 and 70**.
#   - **ViT-based model (ViT-B/16)**:
#     - **60 epochs total**
#     - Learning rate **decayed every 20 epochs**.
# - **Final embeddings** are extracted from **the last layer of CFF module**.
#
# 📌 **Hardware Setup** 🖥️
# - All experiments are conducted on a **single NVIDIA V100 GPU**.
#
# ---

# %% [markdown]
# #### **📊 B. Comparison with State-of-the-Art Methods**
# CLIP-SCGI is compared against **other top CNN and ViT-based ReID methods**.

# %% [markdown]
# ##### **🆚 Comparison with CNN-based Models**
# | **Method** | **MSMT17 (mAP / Top-1)** | **Market-1501 (mAP / Top-1)** | **DukeMTMC (mAP / Top-1)** | **Occluded-Duke (mAP / Top-1)** |
# |------------|----------------|------------------|------------------|------------------|
# | **OSNeT (ICCV 2019)** | 52.9 / 78.7 | 84.9 / 94.8 | 73.5 / 88.6 | - / - |
# | **Auto-ReID (ICCV 2019)** | 52.5 / 78.2 | 85.1 / 94.5 | - / - | - / - |
# | **ISP (ECCV 2021)** | - / - | 88.6 / 95.3 | 80.0 / 89.6 | 52.3 / 62.8 |
# | **PAT (CVPR 2021)** | - / - | 88.0 / 95.4 | 78.2 / 88.8 | 53.6 / 64.5 |
# | **CLIP-ReID (AAAI 2023)** | 63.0 / 84.4 | 89.8 / 95.7 | 80.7 / 90.0 | 53.5 / 61.0 |
# | **PromptSG (CVPR 2024)** | 68.5 / 86.0 | 91.8 / 96.6 | 80.4 / 90.2 | - / - |
# | **Ours (CLIP-SCGI)** | **80.9 / 87.9** | **92.1 / 95.7** | **77.7 / 89.0** | **47.4 / 60.4** |
#
# ✅ **CLIP-SCGI achieves the highest performance on MSMT17 and Market-1501!**
#
# ---

# %% [markdown]
# ##### **🆚 Comparison with ViT-based Models**
# | **Method** | **MSMT17 (mAP / Top-1)** | **Market-1501 (mAP / Top-1)** | **DukeMTMC (mAP / Top-1)** | **Occluded-Duke (mAP / Top-1)** |
# |------------|----------------|------------------|------------------|------------------|
# | **TransReID (ICCV 2021)** | 67.4 / 85.3 | 88.9 / 95.2 | 82.0 / 90.7 | 59.2 / 66.4 |
# | **AAformer (arXiv 2021)** | 63.2 / 83.6 | 87.7 / 95.4 | 80.0 / 90.1 | 58.2 / 67.0 |
# | **PHA (CVPR 2023)** | 68.9 / 86.1 | 90.2 / 96.1 | - / - | - / - |
# | **CLIP-ReID (AAAI 2023)** | 73.4 / 88.7 | 89.6 / 95.5 | 82.5 / 90.0 | 59.5 / 67.1 |
# | **PromptSG (CVPR 2024)** | 87.2 / 92.6 | 94.6 / 97.0 | 81.6 / 91.0 | - / - |
# | **Ours (CLIP-SCGI)** | **88.2 / 92.9** | **96.0 / 97.6** | **81.6 / 91.3** | **59.2 / 67.5** |
#
# ✅ **CLIP-SCGI outperforms ViT-based methods by a large margin!**
#
# ---

# %% [markdown]
# ##### **⚡ C. Training Efficiency**
# 📌 **Comparison of Training Time & Parameters**
#
# | **Dataset** | **Method** | **#Params** | **Training Time (s)** | **mAP** |
# |------------|------------|------------|----------------|------|
# | Market-1501 | CLIP-ReID | 89M | 4689s | 89.6 |
# | Market-1501 | **CLIP-SCGI** | **113M** | **4451s** | **96.0** |
# | MSMT17 | CLIP-ReID | 90M | 12904s | 73.4 |
# | MSMT17 | **CLIP-SCGI** | **113M** | **13534s** | **88.2** |
#
# ✅ **CLIP-SCGI achieves superior accuracy with slightly increased training time**.
#
# ---

# %% [markdown]
# ### **📊 Summary of Comparison with State-of-the-Art Methods (CLIP-SCGI)**
# This section highlights the **performance comparison of CLIP-SCGI against previous state-of-the-art methods** on four **benchmark datasets**:
# 📌 **Market-1501** 🏬 | 📌 **MSMT17** 📷 | 📌 **DukeMTMC-reID** 🎥 | 📌 **Occluded-Duke** 🚶‍♂️
#
# ---

# %% [markdown]
# #### **📌 Key Takeaways from the Comparison**
# 1️⃣ **CLIP-SCGI achieves the highest accuracy across all datasets**, demonstrating **superior ReID performance**.
# 2️⃣ **On MSMT17 (most challenging dataset)**, CLIP-SCGI reaches:
#    - **Rank-1 Accuracy (R1):** **88.2%** 📈
#    - **Mean Average Precision (mAP):** **92.9%** 🚀
#    - 🔥 **This surpasses all previous methods**, including **PromptSG**, by **1.0% (R1) and 0.3% (mAP)**.
# 3️⃣ **Performance boost with CNN backbone**:
#    - 🏆 CLIP-SCGI achieves **80.9% mAP & 87.9% R1** when using **ResNet-50**, outperforming **PromptSG by 12.4% (mAP) and 1.9% (R1)**.
# 4️⃣ **ViT-based CLIP-SCGI also outperforms CLIP-ReID**:
#    - **Improved Rank-1 accuracy** on:
#      ✅ **Market-1501** (+2.1%)
#      ✅ **DukeMTMC** (+1.3%)
#      ✅ **Occluded-Duke** (+0.4%)
#    - 🔥 **Proves CLIP-SCGI's effectiveness across all datasets**.
#
# ---

# %% [markdown]
# #### **📌 Performance Comparison with Previous State-of-the-Art**

# %% [markdown]
# ##### **🆚 CLIP-SCGI vs. Previous CNN-Based Methods**
# | **Method** | **MSMT17 (mAP / R1)** | **Market-1501 (mAP / R1)** | **DukeMTMC (mAP / R1)** | **Occluded-Duke (mAP / R1)** |
# |------------|----------------|------------------|------------------|------------------|
# | **OSNeT (ICCV 2019)** | 52.9 / 78.7 | 84.9 / 94.8 | 73.5 / 88.6 | - / - |
# | **ISP (ECCV 2021)** | - / - | 88.6 / 95.3 | 80.0 / 89.6 | 52.3 / 62.8 |
# | **CDNet (CVPR 2021)** | 54.7 / 78.9 | 86.0 / 95.1 | 76.8 / 88.6 | - / - |
# | **CLIP-ReID (AAAI 2023)** | 63.0 / 84.4 | 89.8 / 95.7 | 80.7 / 90.0 | 53.5 / 61.0 |
# | **PromptSG (CVPR 2024)** | 68.5 / 86.0 | 91.8 / 96.6 | 80.4 / 90.2 | - / - |
# | **Ours (CLIP-SCGI)** | **80.9 / 87.9** 🏆 | **92.1 / 95.7** | **77.7 / 89.0** | **47.4 / 60.4** |
#
# ✅ **CLIP-SCGI dominates MSMT17 (CNN-based) with a 12.4% mAP boost!**
#
# ---

# %% [markdown]
# ##### **🆚 CLIP-SCGI vs. Previous ViT-Based Methods**
# | **Method** | **MSMT17 (mAP / R1)** | **Market-1501 (mAP / R1)** | **DukeMTMC (mAP / R1)** | **Occluded-Duke (mAP / R1)** |
# |------------|----------------|------------------|------------------|------------------|
# | **TransReID (ICCV 2021)** | 67.4 / 85.3 | 88.9 / 95.2 | 82.0 / 90.7 | 59.2 / 66.4 |
# | **AAformer (arXiv 2021)** | 63.2 / 83.6 | 87.7 / 95.4 | 80.0 / 90.1 | 58.2 / 67.0 |
# | **PHA (CVPR 2023)** | 68.9 / 86.1 | 90.2 / 96.1 | - / - | - / - |
# | **CLIP-ReID (AAAI 2023)** | 73.4 / 88.7 | 89.6 / 95.5 | 82.5 / 90.0 | 59.5 / 67.1 |
# | **PromptSG (CVPR 2024)** | 87.2 / 92.6 | 94.6 / 97.0 | 81.6 / 91.0 | - / - |
# | **Ours (CLIP-SCGI)** | **88.2 / 92.9** 🏆 | **96.0 / 97.6** | **81.6 / 91.3** | **59.2 / 67.5** |
#
# ✅ **CLIP-SCGI improves ViT-based Rank-1 accuracy on**:
# - **Market-1501** (+2.1%)
# - **DukeMTMC** (+1.3%)
# - **Occluded-Duke** (+0.4%)
#
# 🔥 **New state-of-the-art performance on MSMT17 (88.2% R1, 92.9% mAP)!**
#
# ---

# %% [markdown]
# #### **📌 Key Findings**
# 📍 **CLIP-SCGI surpasses all existing methods** in person re-identification benchmarks.
# 📍 **Most significant improvement** on **MSMT17** and **Market-1501** datasets.
# 📍 **Strong results across both CNN & ViT architectures**, proving flexibility.
# 📍 **Achieves best Rank-1 accuracy and mAP compared to previous CLIP-based models**.
# 📍 **Demonstrates state-of-the-art performance without re-ranking!** 🚀
#
# ---

# %% [markdown]
# ### **📊 Training Efficiency Comparison: CLIP-SCGI vs. CLIP-ReID**
#
# This section **compares the training efficiency** of **CLIP-SCGI** with **CLIP-ReID**, analyzing three key factors:
#
# 📌 **Parameter Count**
# 📌 **Training Time**
# 📌 **Accuracy (mAP and Rank-1 performance)**
#
# ---

# %% [markdown]
# #### **📌 Key Findings from Training Efficiency Comparison**
# 1️⃣ **CLIP-SCGI has 26% more parameters than CLIP-ReID** 📈, but **training time remains the same** due to an optimized one-stage training approach.
# 2️⃣ **CLIP-SCGI achieves significantly higher accuracy**:
#    - **Market-1501**: **mAP 96.0%** vs. **89.6%** (CLIP-ReID) ⬆️ **+6.4% improvement**
#    - **MSMT17**: **mAP 88.2%** vs. **73.4%** (CLIP-ReID) ⬆️ **+14.8% improvement**
# 3️⃣ **CLIP-SCGI eliminates the need for inefficient two-stage training** and provides **better performance with a more streamlined approach**.
# 4️⃣ **Despite higher model complexity, training time remains efficient**, making CLIP-SCGI scalable for large datasets.
#
# ---

# %% [markdown]
# #### **📌 Training Efficiency Breakdown**
# | **Method**  | **# Parameters** | **Training Time (Market-1501)** | **Training Time (MSMT17)** | **Market-1501 (mAP)** | **MSMT17 (mAP)** |
# |------------|--------------|----------------------|----------------------|----------------|----------------|
# | **CLIP-ReID** | 89M  | 4689s ⏳ | 12,904s ⏳ | **89.6%** 📉 | **73.4%** 📉 |
# | **CLIP-SCGI (Ours)** | 113M (+26%) | **4451s** ⚡ (**faster!**) | **13,534s** (almost same) | **96.0%** 🚀 | **88.2%** 🚀 |
#
# ✅ **Despite having 26% more parameters, CLIP-SCGI trains just as fast as CLIP-ReID!**
# ✅ **Achieves **+6.4%** higher accuracy on Market-1501 and **+14.8%** higher accuracy on MSMT17**!
#
# ---

# %% [markdown]
# #### **📌 Ablation Study: Impact of Key Components**
# Table III examines how different components contribute to performance:

# %% [markdown]
# ##### **🧩 Components Tested**
# 1️⃣ **CGI (Caption-Guided Inversion)** 📝
# 2️⃣ **CFF (Contextual Feature Fusion)** 🔀
# 3️⃣ **Both CGI + CFF Combined** 🔥
#
# | **Component Tested** | **Market-1501 (mAP / R1)** | **MSMT17 (mAP / R1)** |
# |----------------------|-----------------|----------------|
# | **CGI Only** ✅ | 89.6 / 95.5 | 71.5 / 87.6 |
# | **CFF Only** ✅ | 93.6 / 95.6 | 85.2 / 90.9 |
# | **CGI + CFF (Full Model)** ✅ ✅ | **96.0 / 97.6** 🚀 | **88.2 / 92.9** 🚀 |
#
# 🔎 **Key Takeaways from Ablation Study**
# ✅ **CGI (Caption-Guided Inversion) alone improves performance but is insufficient for maximum accuracy.**
# ✅ **CFF (Contextual Feature Fusion) significantly boosts performance, especially on MSMT17.**
# ✅ **Combining both CGI + CFF achieves the best accuracy**, proving that both components are essential!
#
# ---

# %% [markdown]
# ##### **📢 Final Thoughts**
# 🔥 **CLIP-SCGI is significantly more accurate than CLIP-ReID** while maintaining **efficient training**.
# 🔥 **Key components (CGI + CFF) work together to maximize performance**, leading to **state-of-the-art results**!
#
# ---

# %% [markdown]
# ### **📊 Ablation Studies: Understanding CLIP-SCGI's Components & Hyperparameters**
#
# This section presents **a detailed breakdown of key components** that influence the performance of **CLIP-SCGI** on **MSMT17** and **Market-1501** datasets.
#
# ---

# %% [markdown]
# #### **📌 Key Findings from Ablation Studies**
#
# 1️⃣ **Effectiveness of CGI Module (Caption-Guided Inversion) 📌**
#    - Removing **CGI** and using only the phrase **"a photo of a person"** significantly reduces performance.
#    - **mAP decreases by 2.4% (Market-1501) and 3.0% (MSMT17)** when **CGI is removed** (Table III, No.2 vs. No.3).
#    - **Rank-1 accuracy (R1) drops by 2% on both datasets**, proving CGI’s importance in guiding fine-grained feature learning.
#
# 2️⃣ **Importance of CFF Module (Contextual Feature Fusion) 🔀**
#    - The **CFF module improves fusion between image and text embeddings** for better feature alignment.
#    - Without CFF, performance **drops significantly** in mAP and Rank-1 accuracy (Table III, No.1 vs. No.3).
#    - **Key Benefit:** CFF helps the model **focus on key identity-related regions** rather than background distractions.
#
# 3️⃣ **Impact of Semantic Guidance in CFF 📝**
#    - Replacing **semantic text-based guidance ("a photo of a S* person") with image features** reduces performance:
#      - **Market-1501**: **mAP -1.9%, R1 -0.9%**
#      - **MSMT17**: **mAP -1.5%, R1 -0.4%**
#      - **DukeMTMC**: **mAP -4.7%, R1 -1.8%**
#    - **Text-based semantic prompts are crucial** because they help the model focus **on identity details instead of irrelevant backgrounds**.
#
# 4️⃣ **Optimal Depth of CGI & Number of Learnable Queries 🔢**
#    - **CGI Depth Impact (Fig. 4a) 📏**
#      - Depth **5 gives the best mAP** while **depth 6 achieves the best Rank-1 accuracy**.
#      - However, **depth 1 provides the best trade-off between performance and efficiency**.
#    - **Number of Learnable Queries (qK) (Fig. 4b) 🧠**
#      - Testing qK = **1, 2, 4, 8** shows that **qK = 2 gives the best performance**.
#      - A longer prompt (qK > 2) **hurts performance** by adding unnecessary complexity.
#
# ---

# %% [markdown]
# #### **📌 Summary of Ablation Study Results (Table IV)**
# | **Method** | **Market-1501 (mAP/R1)** | **MSMT17 (mAP/R1)** | **DukeMTMC (mAP/R1)** |
# |------------|-----------------|----------------|----------------|
# | **Full CLIP-SCGI** ✅ | **96.0 / 97.6** 🚀 | **88.2 / 92.9** 🚀 | **81.5 / 90.6** 🚀 |
# | **Replace Semantic Query with Image Features** ❌ | **94.1 / 96.7** ⬇️ | **86.7 / 92.5** ⬇️ | **76.8 / 88.8** ⬇️ |
#
# ---

# %% [markdown]
# #### **📢 Final Takeaways**
# ✅ **Both CGI & CFF are critical for achieving high performance in ReID.**
# ✅ **Text-based semantic guidance significantly improves model focus, outperforming image-based features.**
# ✅ **Depth 1 for CGI & prompt length 2 strike the best trade-off between efficiency & accuracy.**
#
# ---

# %% [markdown]
# ### **📌 Visualization & Qualitative Analysis of CLIP-SCGI**
#
# This section provides a **visual comparison** between **CLIP-SCGI** (our method) and **CLIP-ReID**, demonstrating how our approach improves person re-identification.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **🔍 1) Retrieval Result Visualization (Fig. 5)**
# 📌 **Objective**: Compare the **top-10 retrieved results** from **CLIP-SCGI (first row)** vs. **CLIP-ReID (second row)** on the **MSMT17 dataset**.
# 📌 **Key Observations**:
# - 🔹 **More Accurate Retrieval**: CLIP-SCGI correctly retrieves more relevant identities than CLIP-ReID.
# - 🔹 **Handles Challenging Conditions**:
#   - Performs well under **blurriness and low lighting**.
#   - Accurately **identifies subjects despite occlusions**.
# - 🔹 **Better Feature Differentiation**:
#   - Even for **visually similar individuals**, our method distinguishes subtle differences (e.g., **hair length, clothing styles, shoes**).
#   - CLIP-ReID, in contrast, **struggles with these nuances**, leading to **incorrect matches** (highlighted in red).
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **🎯 2) Attention Map Visualization (Fig. 6)**
# 📌 **Objective**: Compare where CLIP-SCGI and CLIP-ReID **focus their attention** in images.
# 📌 **Key Insights**:
# - **CLIP-ReID**:
#   - **General attention on pedestrian regions**, but **fails to capture fine details**.
#   - Misses key features like **shoes, backpacks, and distinguishing accessories**.
#   - Background distractions **interfere** with its focus.
# - **CLIP-SCGI (Ours)**:
#   - **Precisely attends to individual identity-specific details** (e.g., **clothes, accessories, body parts**).
#   - **Ignores background distractions**, reducing misidentifications.
#   - Performs well **even in blurry or occluded scenes**.
#
# ---

# %% [markdown]
# #### **📢 Final Takeaways**
# ✅ **CLIP-SCGI retrieves more correct matches and is robust under challenging conditions.**
# ✅ **Attention maps show that CLIP-SCGI focuses on discriminative identity features better than CLIP-ReID.**
# ✅ **Semantic guidance (via captions) significantly enhances feature extraction, leading to superior recognition accuracy.**
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **📌 Final Summary: CLIP-SCGI for Person Re-Identification**
# ---

# %% [markdown]
# #### **🚀 Key Contributions of CLIP-SCGI**
# 1. **Bridging the Gap in Re-ID**
#    - Traditional **CLIP-ReID** relies on **implicit text embeddings**, which **require complex pretraining** and fail to provide **fine-grained person details**.
#    - **CLIP-SCGI** solves this by **explicitly generating textual descriptions** (captions) for person images using **pretrained captioning models** like **LLAVA**.
#
# 2. **Unimodal to Bimodal Data Augmentation**
#    - Traditional ReID datasets **only contain images** (unimodal).
#    - **CLIP-SCGI augments these datasets** by **synthesizing captions**, enabling **multi-modal (text + image) learning**.
#    - This allows **CLIP to be trained more effectively** for **ReID tasks**.
#
# 3. **Key Technical Innovations**
#    - **Caption-Guided Inversion (CGI) Module**
#      - Converts image features into **pseudo-word tokens** for better text-image alignment.
#      - Helps **refine identity-specific details** from captions.
#    - **Contextual Feature Fusion (CFF) Module**
#      - **Merges textual and visual features**, allowing the model to focus on **identity-relevant regions**.
#      - Reduces **background distractions**.
#
# 4. **📊 Superior Performance over State-of-the-Art**
#    - **Outperforms previous methods (CLIP-ReID, PromptSG, TransReID, etc.)**
#    - **MSMT17 Dataset Results**:
#      - CLIP-SCGI achieves **88.2% mAP** (+14.8% over CLIP-ReID).
#      - **Rank-1 Accuracy of 92.9%**, surpassing all prior benchmarks.
#
# ---

# %% [markdown]
# #### **📢 Future Research Directions**
# 🔹 **Remove Dependence on External Captioning Models**
#    - Currently, CLIP-SCGI **relies on LLAVA** (or similar models) to generate **offline captions**.
#    - Future research aims to **eliminate this extra step** by **directly extracting implicit textual embeddings** from **pretrained multimodal models**.
#
# 🔹 **Improve Captioning for Occluded Cases**
#    - Fig. 7 highlights how **occlusions impact caption accuracy**.
#    - Future improvements will refine **robust caption generation for occluded identities**.
#
# 🔹 **Real-Time Inference Optimization**
#    - Explore **lightweight fusion techniques** to **speed up inference** while maintaining **high accuracy**.
#
# ---

# %% [markdown]
# #### **🎯 Conclusion**
# ✅ **CLIP-SCGI redefines person Re-ID by integrating textual descriptions into image-based retrieval.**
# ✅ **This approach enhances feature extraction, leading to state-of-the-art results on multiple datasets.**
# ✅ **Future work will focus on removing dependency on explicit captions and improving efficiency for real-time applications.**
