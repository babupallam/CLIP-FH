# %% [markdown]
# # References
#   - **Paper name:** Multi-Branch with Attention Network for Hand-Based Person Recognition
#   - **Authors:** Nathanael L. Baisa, Bryan Williams, Hossein Rahmani, Plamen Angelov, Sue Black
#   - **Paper Link:** https://arxiv.org/abs/2108.02234
#   - **Github Link:** https://github.com/nathanlem1/MBA-Net

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Abstract
#
#  **Main Idea:**
# This paper proposes a new **hand-based person recognition** method, called **MBA-Net**, for criminal investigations where only hand images are available (e.g., sexual abuse cases).
#
#  **Key Features of MBA-Net:**
#  **Multi-Branch Architecture**  Uses **multiple branches** to extract different features from the hand image.
#  **Attention Mechanisms**  Includes **channel and spatial attention modules** to focus on important hand details and ignore background noise.
#  **Global Feature Learning**  Also includes a **global branch** (without attention) to capture overall hand structure.
#  **Improved Spatial Understanding**  Uses **relative positional encodings** in the spatial attention module to understand pixel locations better.
#
#  **Performance:**
# - Tested on **two large multi-ethnic public hand datasets**.
# - **Achieves state-of-the-art results**, outperforming existing hand-based identification methods.
# - Source code is available for replication: **[GitHub Link](https://github.com/nathanlem1/MBA-Net)**.
#
#  **Key Contribution:**
# This method **improves hand-based person recognition** using deep learning, making it **more accurate and reliable for criminal investigations** where hands are the only evidence.

# %% [markdown]
# ## **References Used in the Paper**
#
# The references used in this paper provide **background knowledge and key contributions** related to **hand-based person recognition, biometrics, deep learning, attention mechanisms, and person re-identification (Re-ID).** Below is a categorized breakdown:
#
# ---
#
# ### **1. Hand-Based Biometrics & Person Recognition**
# These references focus on **biometric recognition using hands, fingers, or knuckle patterns**:
# - **[1]** Soft biometric traits and their potential in recognition.
# - **[2]** A previous work by the same authors on deep learning for hand-based identification.
# - **[3]** HandNet  A deep learning model for hand-based identification.
# - **[4]** Fusion of finger knuckle patterns for authentication.
# - **[5]** 11K Hands dataset  A large dataset used for gender recognition and biometric ID.
# - **[11]** Minor knuckle patterns from the palm dorsal surface for person identification.
#
#  **Key Takeaway:** These studies provide **foundations for hand-based recognition techniques**, including datasets, biometric feature extraction, and deep learning applications.
#
# ---
#
# ### **2. Vision Transformers & Deep Learning for Recognition**
# These references discuss **modern deep learning architectures** and **attention mechanisms** used in vision tasks:
# - **[6]** A survey of Transformers in vision applications.
# - **[10]** Global self-attention networks for image recognition.
# - **[12]** Deep Residual Learning (ResNet)  A backbone architecture used in many vision tasks.
# - **[13]** Inception-V4 and ResNets impact on deep learning.
# - **[15]** Rethinking Inception architecture for vision tasks.
#
#  **Key Takeaway:** These works contribute **deep learning backbones** and **self-attention mechanisms** that the MBA-Net model builds upon.
#
# ---
#
# ### **3. Attention-Based Person Re-Identification (Re-ID)**
# These references focus on **deep learning models for person Re-ID, particularly using attention mechanisms**:
# - **[7]** ABD-Net: Uses attention mechanisms for diverse and robust Re-ID.
# - **[8]** Relation-aware global attention for person Re-ID.
# - **[9]** Self-attention with relative position representation (used in NLP and vision tasks).
# - **[14]** A strong baseline for deep person Re-ID.
# - **[16]** Large-scale person Re-ID benchmark.
#
#  **Key Takeaway:** These studies highlight **attention mechanisms** and **Re-ID benchmarks**, which MBA-Net adapts for hand-based recognition.
#
# ---
#
# ### **Overall Importance of the References**
#  **They justify the research gap**  While there are **many person Re-ID studies, most focus on full-body images**, not hands.
#  **They provide technical foundations**  Attention mechanisms, deep learning backbones, and self-attention models are essential for MBA-Net.
#  **They include datasets and previous methods**  The 11K Hands dataset and other biometric datasets help validate the research.
#
# ---

# %% [markdown]
# ## **Introduction**
#  **Main Idea:**
# Biometric identification using **hand images** is gaining attention for **person recognition**, especially in **criminal investigations** where hands might be the only available evidence (e.g., sexual abuse cases).
#
# ---
#
# ### **1 Why Hand Images for Person Recognition?**
#  Hand images have **strong and stable features** after adulthood.
#  Compared to other biometric traits (face, iris, fingerprints), **hand images are more stable** and have **less variability** over time.
#  Digital cameras can **capture hand images easily**, making them useful for **real-world criminal investigations**.
#
# ---
#
# ### **2 Previous Approaches & Their Limitations**
#  **CNN + SVM Approach:**
# - Earlier works **trained CNNs on hand images** and extracted features for classification using **Support Vector Machines (SVMs)**.
# - Some methods used **additional modalities like Near-Infrared (NIR) images** to improve performance.
#  **Limitation:** These methods are **not end-to-end**, meaning they require **separate feature extraction and classification steps**.
#
#  **Self-Attention in Deep Learning:**
# - **Transformers** use **self-attention mechanisms** to capture long-term interactions across pixels, channels, and feature maps.
# - Attention-based person Re-ID methods ([7], [8]) have been successful, but they **focus on full-body images**.
#  **Limitation:** Applying attention **across all network layers is computationally expensive**, especially for large image dimensions.
#
#  **Problem with Self-Attention:**
# - Attention mechanisms **do not naturally model position information**.
# - Relative positional encoding was introduced in **NLP ([9])** and later adapted for vision tasks ([10]).
#  **Limitation:** Existing methods use attention mechanisms **without considering pixel positions**, leading to **equivariance to pixel shuffling** (i.e., position confusion).
#
# ---
#
# ### **3 The Proposed MBA-Net Model**
#  **Solution: Multi-Branch with Attention Network (MBA-Net)**
# A novel **hand-based person recognition model** that:
#  Uses **channel & spatial attention** in separate branches **(multi-branch design)**.
#  Includes **a global branch** (without attention) to **capture full hand structure**.
#  Incorporates **relative positional encodings** to improve **spatial feature learning**.
#  Applies attention modules **only to low-resolution feature maps** for **better computational efficiency**.
#  Works **end-to-end** without requiring **separate feature extraction & classification steps**.
#
# ---
#
# ### **4 Contributions of This Work**
#  **Key Innovations:**
# 1 **Multi-Branch Attention Network**: Combines **channel & spatial attention** with a global branch for **efficient hand-based recognition**.
# 2 **Relative Positional Encoding**: Captures **spatial positions of pixels** to address **attention mechanism limitations**.
# 3 **State-of-the-Art Evaluations**: Tested on **two large multi-ethnic hand datasets** (**11k Hands** & **HD dataset**).
#
# ---
#
# ### **5 Paper Structure**
# - **Section II**: Details of MBA-Net architecture & attention modules.
# - **Section III**: Experimental results on hand datasets.
# - **Section IV**: Conclusion & future research directions.
#
# ---
#
# ### ** Key Takeaways**
#  **Hand-based person recognition is useful for crime investigations** where hand images may be the **only available evidence**.
#  **Existing methods (CNNs, full-body Re-ID) have limitations** like **high computational cost and lack of position awareness**.
#  **MBA-Net solves these issues** by using a **multi-branch attention mechanism** and **relative positional encoding** for better accuracy.
#
# ---

# %% [markdown]
# ## **Section II: Proposed Method (MBA-Net)**
#
#  **Main Idea:**
# The **MBA-Net model** improves **hand-based person recognition** by using two **attention modules** (Channel Attention and Spatial Attention with Relative Positional Encoding) along with a **global feature branch**. These attention mechanisms help the model focus on important hand details while ignoring irrelevant backgrounds.
#
# ---
#
# ## **1 Channel Attention Module (CAM)**
#
# ![image.png](data:image/png;base64,...)
# ---
#
# ## **2 Spatial Attention Module with Relative Positional Encoding (SAM-RPE)**
#
# ![image.png](data:image/png;base64,...)
#
#
# ---
#
# ## **3 Network Architecture Overview**
#  **Key Idea:**
# - **Combines attention modules with ResNet50 backbone** in a **multi-branch design** for efficient hand-based recognition.
#
#  **Architecture Details:**
# - **Uses ResNet50** (pre-trained on ImageNet) as the base model.
# - **Three parallel branches**:
#   1 **Channel Attention Branch (CAM)**
#   2 **Spatial Attention Branch (SAM-RPE)**
#   3 **Global Feature Branch (no attention, captures overall hand structure)**
# - **Each branch has**:
#    Fully Connected (FC) layer
#    Batch Normalization (BN)
#    Leaky ReLU (LReLU)
#    Dropout (0.5) to reduce overfitting
# - **Final Feature Representation**:
#   - During **training**, each branch makes an independent **ID prediction** (using Cross-Entropy Loss).
#   - During **testing**, the feature maps from all **three branches are concatenated** into a **6144-D feature vector** and compared using **cosine distance** for person recognition.
#
#  **Key Benefit:**
# - **More efficient computation** (uses attention only in later layers).
# - **Robust recognition** (combines local and global features).
# - **End-to-end training** (unlike previous CNN+SVM methods).
#
# ---
#
# ### ** Key Takeaways**
#  **MBA-Net improves accuracy by combining channel & spatial attention modules.**
#  **Relative Positional Encoding helps maintain spatial consistency for hand images.**
#  **Uses ResNet50 but can be adapted to other networks like Inception.**
#  **Multi-branch design balances computational efficiency & feature richness.**
#
# ---

# %% [markdown]
# ## **Section III: Experimental Results**
#
#  **Main Idea:**
# The **MBA-Net model** is tested on two **hand-based person recognition datasets** and compared with existing methods. The results show that MBA-Net **outperforms all other models**, achieving state-of-the-art accuracy in both **same-domain (trained and tested on the same dataset)** and **cross-domain (trained on one dataset, tested on another)** evaluations.
#
# ---
#
# ## **1 Experimental Setup**
# ### ** Datasets Used**
#  **11k Hands Dataset** ([Dataset Link](https://sites.google.com/view/11khands))
# - **190 subjects** (Identities).
# - Divided into **4 sub-datasets**:
#   - **Right dorsal** (143 identities)
#   - **Left dorsal** (146 identities)
#   - **Right palmar** (143 identities)
#   - **Left palmar** (151 identities)
#
#  **Hong Kong Polytechnic University Hand Dorsal (HD) Dataset** ([Dataset Link](http://www4.comp.polyu.edu.hk/~csajaykr/knuckleV2.htm))
# - **502 identities** in total.
# - **Additional 213 subjects** with unclear images included in the gallery.
#
# ### ** Data Partitioning**
# - **Training Set**  First half of identities.
# - **Testing Set**  Second half of identities.
# - **Gallery Set**  One image per identity from the test set.
# - **Query Set**  Remaining test images.
#
#  **Data Statistics:**
# | Dataset | Gallery Images | Query Images |
# |---------|--------------|-------------|
# | **Right Dorsal (11k)** | 290 | 971 |
# | **Left Dorsal (11k)** | 290 | 988 |
# | **Right Palmar (11k)** | 290 | 917 |
# | **Left Palmar (11k)** | 290 | 948 |
# | **HD Dataset** | 1,593 | 1,992 |
#
#  **Why This Setup?**
# - Ensures a **fair evaluation** with a fixed number of images for training and testing.
# - **Random sampling** helps prevent bias in performance evaluation.
# - The experiment is **repeated 10 times**, and the **average performance is reported**.
#
# ---
#
# ## **2 Implementation Details**
#  **Framework:** PyTorch
#  **Hardware:** NVIDIA GeForce RTX 2080 Ti GPU
#  **Input Image Processing:**
#   - Resized to **356356**  Randomly cropped to **324324**
#   - **Data Augmentation:** Random horizontal flip, color jittering, and normalization
#   - **Testing Phase:** Only normalization, no cropping
#
#  **Training Settings:**
# | Parameter | Value |
# |-----------|-------|
# | **Batch Size** | 20 |
# | **Optimizer** | Adam |
# | **Weight Decay** | \(5 \times 10^{-4}\) (L2 Regularization) |
# | **Loss Function** | Cross-Entropy |
# | **Epochs** | 70 |
# | **Learning Rate Schedule** |
# | First 10 Epochs | Linear increase from \(8 \times 10^{-6}\) to \(8 \times 10^{-4}\) |
# | After 40 Epochs | Decayed to \(4 \times 10^{-4}\) |
# | After 60 Epochs | Decayed to \(2 \times 10^{-4}\) |
#
#  **Why This Training Setup?**
#  **Prevents overfitting** using dropout and label smoothing.
#  **Uses warmup strategy** for stable learning.
#  **Fine-tunes backbone (ResNet50) carefully** by using a lower learning rate for pre-trained layers and a higher learning rate for new layers.
#
# ---
#
# ## **3 Performance Evaluation**
# ### ** Evaluation Metrics**
# 1 **Mean Average Precision (mAP)**  Measures the model's ability to retrieve relevant matches.
# 2 **Rank-1 Accuracy**  Measures how often the correct identity is the top-ranked prediction.
#
# ---
#
# ### ** Comparison with Other Methods**
#  **Same-Domain Performance** (Trained & tested on the same dataset)
#
# | **Method** | **Right Dorsal (11k)** | **Left Dorsal (11k)** | **Right Palmar (11k)** | **Left Palmar (11k)** | **HD Dataset** |
# |------------|----------------|----------------|----------------|----------------|----------------|
# | **GPA-Net [2]** | 94.80% (mAP: 95.72%) | 94.87% (mAP: 95.93%) | 95.83% (mAP: 96.31%) | 95.72% (mAP: 96.20%) | 94.64% (mAP: 95.08%) |
# | **RGA-Net [8]** | 94.77% (mAP: 95.67%) | 95.30% (mAP: 95.98%) | 92.66% (mAP: 93.58%) | 94.95% (mAP: 95.67%) | 95.06% (mAP: 95.39%) |
# | **ABD-Net [7]** | 95.89% (mAP: 96.76%) | 94.26% (mAP: 95.34%) | 96.21% (mAP: 96.91%) | 95.54% (mAP: 96.01%) | 94.93% (mAP: 95.38%) |
# | **MBA-Net (Ours)** | **97.45% (mAP: 97.98%)** | **96.71% (mAP: 97.41%)** | **98.05% (mAP: 98.42%)** | **97.42% (mAP: 97.84%)** | **95.12% (mAP: 95.54%)** |
#
#  **Key Insights:**
#  **MBA-Net outperforms all other models across all datasets.**
#  **Highest accuracy on right palmar (98.05% Rank-1, 98.42% mAP).**
#  **Achieves better generalization compared to body-based Re-ID models.**
#
# ---
#
# ### ** Cross-Domain Performance** (Trained on **Right Dorsal (11k)**, tested on **HD Dataset**)
#
# | **Method** | **D-r (11k)  D-r (11k) test** | **D-r (11k)  HD test** |
# |------------|------------------|------------------|
# | **GPA-Net [2]** | 94.80% (mAP: 95.72%) | 83.02% (mAP: 84.65%) |
# | **RGA-Net [8]** | 94.77% (mAP: 95.67%) | 77.80% (mAP: 80.07%) |
# | **ABD-Net [7]** | 95.89% (mAP: 96.76%) | 71.22% (mAP: 73.86%) |
# | **MBA-Net (Ours)** | **97.45% (mAP: 97.98%)** | **84.41% (mAP: 85.98%)** |
#
#  **Key Insights:**
#  **MBA-Net generalizes better than other methods when tested on a different dataset.**
#  **Most other models experience significant performance drops.**
#  **MBA-Net maintains 84.41% Rank-1 accuracy in cross-domain testing, significantly better than ABD-Net (71.22%).**
#
# ---
#
# ## **4 Ablation Study**
#  **Testing how different components of MBA-Net contribute to performance.**
#
# | **Model Version** | **Rank-1 Accuracy (%)** | **mAP (%)** |
# |------------------|------------------|------------------|
# | **Global Branch Only (ResNet50 modified)** | 95.43% | 95.95% |
# | **+ Spatial Attention (No RPE)** | 96.50% | 96.73% |
# | **+ Channel Attention** | 97.41% | 97.65% |
# | **+ Relative Positional Encoding (Final MBA-Net)** | **98.05%** | **98.42%** |
#
#  **Key Insights:**
#  **Each attention module improves performance.**
#  **Relative Positional Encoding (RPE) further boosts accuracy.**
#  **Final MBA-Net achieves the highest accuracy (98.05%).**
#
# ---
#
# ### ** Key Takeaways**
#  **MBA-Net outperforms existing models in both same-domain & cross-domain evaluations.**
#  **Combining spatial & channel attention improves recognition accuracy.**
#  **Relative Positional Encoding makes the model more robust.**
#  **Best results on right palmar images (98.05% Rank-1, 98.42% mAP).**
#
# ---

# %% [markdown]
# ## **Section IV: Conclusion**
#
#  **Main Idea:**
# The **MBA-Net model** successfully improves **hand-based person recognition** by integrating **multi-branch attention mechanisms**. The model effectively learns **deep feature representations**, making it a **robust solution for identifying individuals from hand images, particularly in criminal investigations**.
#
# ---
#
# ### **1 Key Contributions of MBA-Net**
#  **Multi-Branch Design:**
# - Uses **three branches**:
#   - **Channel Attention Module (CAM)**  Focuses on discriminative feature channels.
#   - **Spatial Attention Module (SAM-RPE)**  Highlights important spatial regions.
#   - **Global Feature Branch** (No attention)  Preserves overall structure.
#
#  **Relative Positional Encoding (RPE):**
# - **Enhances spatial understanding** of hand images.
# - **Overcomes pixel shuffling issues** in attention mechanisms.
#
#  **Efficient & Robust Recognition:**
# - Suppresses **irrelevant background noise** while highlighting **key hand features**.
# - Works well in **less controlled environments** (e.g., varying lighting, hand positioning).
#
# ---
#
# ### **2 Superior Performance Over Existing Methods**
#  **Extensive testing on two large hand datasets (11k Hands & HD Dataset).**
#  **Achieved state-of-the-art results** with the highest **Rank-1 accuracy & mAP**.
#  **More effective than body-based Re-ID models when adapted for hands.**
#
#  **Real-World Application:**
# - **Useful for criminal investigations**, where hand images are often the only available evidence.
#
# ---
#
# ### ** Key Takeaways**
#  **MBA-Net is a significant advancement in hand-based biometric recognition.**
#  **The combination of multi-branch attention & positional encoding improves accuracy.**
#  **Performs better than existing models, making it ideal for forensic applications.**
#
# ---
#
#  **Final Thought:** This study **proves that hand-based person recognition is a viable and effective biometric method** when using **attention-enhanced deep learning models** like MBA-Net.
#
# ---

# %% [markdown]
# ## **Structure of MBA-Net**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Explanation of the Figure: Structure of MBA-Net**
#
#  **Main Idea:**
# This figure illustrates the **architecture of MBA-Net**, showing how **hand images are processed** through different branches to extract features for **hand-based person identification**.
#
# ---
#
# ### ** Step-by-Step Breakdown of the Figure**
#
# #### **1 Input: Hand Image**
# - The **input image** (hand image) has **height (H) and width (W)**.
# - This image is fed into the **Backbone Network (ResNet50)**.
#
# ---
#
# #### **2 Backbone Network (Feature Extractor)  ResNet50**
# - **Purpose:** Extract important **low-level and high-level features** from the hand image.
# - The ResNet50 **pretrained on ImageNet** is used up to **layer 3** (meaning the first three layers are unchanged).
# - The extracted feature map is then **passed into three separate branches**.
#
# ---
#
# #### **3 Multi-Branch Network**
# After passing through ResNet50, the model **splits into three branches**:
#
#  **1st Branch: Spatial Attention (SAM-RPE)  S3, L4, S4**
#    - **Focuses on spatial regions** in the hand image (important pixels).
#    - Includes **GAP (Global Average Pooling)**, followed by a **fully connected (FC) layer**, batch normalization (BN), leaky ReLU (LReLU), and dropout.
#    - Produces a **2048-dimensional feature vector** (**vector s**  **vector s'**).
#
#  **2nd Branch: Global Feature Branch  L4**
#    - Extracts **general features** without attention mechanisms.
#    - Includes **GAP, FC, BN, LReLU, and Dropout**.
#    - Produces a **2048-dimensional feature vector** (**vector g**  **vector g'**).
#
#  **3rd Branch: Channel Attention (CAM)  C3, L4, C4**
#    - **Identifies the most important feature channels** from the image.
#    - Similar to the other branches, it includes **GAP, FC, BN, LReLU, and Dropout**.
#    - Produces a **2048-dimensional feature vector** (**vector c**  **vector c'**).
#
# ---
#
# #### **4 Final Identity Prediction**
# - Each branch independently **predicts the identity of the hand image**.
# - The **fully connected (FC) layers** in each branch output identity predictions.
# - In the final model:
#   - During training, all three branches contribute **independently**.
#   - During testing, all feature vectors (**s, g, c**) are concatenated into a **single 6144-dimensional feature vector** for final identification.
#
# ---
#
# ### ** Key Takeaways from the Figure**
#  The **hand image** is processed using **ResNet50 as the backbone**.
#  Three **parallel branches** extract different types of features:
#    - **Spatial Attention (S3, S4)**  Highlights important regions.
#    - **Global Features (L4)**  Extracts overall hand structure.
#    - **Channel Attention (C3, C4)**  Focuses on the most important feature channels.
#  Each branch outputs **2048-dimensional feature vectors**, which are **used to predict identity**.
#  **Final feature fusion** (concatenation) is done during testing for the best accuracy.
#
# ---
#
# ### ** Why This Architecture?**
# - **More Accurate:** Each branch extracts **complementary information** for better identification.
# - **More Robust:** Attention mechanisms **filter out noise and background** while focusing on hand features.
# - **Computationally Efficient:** Uses attention only at later layers, reducing processing cost.
#
# ---

# %% [markdown]
# ## **Attention Modules (CAM and SAM-RPE) in MBA-Net**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Explanation of Fig. 1: Attention Modules (CAM and SAM-RPE) in MBA-Net**
#
#  **Main Idea:**
# This figure explains the **two attention mechanisms** used in the MBA-Net model:
# 1. **Channel Attention Module (CAM)**
# 2. **Spatial Attention Module with Relative Positional Encoding (SAM-RPE)**
#
# Both modules help the model focus on **important features in hand images** while ignoring background noise.
#
# ---
#
# ## ** (a) Channel Attention Module (CAM)**
#  **Purpose:**
# - Identifies **which feature channels** are the most important for recognizing the hand.
# - Helps the model **focus on relevant feature maps** and ignore unnecessary ones.
#
#  **How it Works:**
# 1 The input feature map **\(E_i\)** (size: **C  H  W**) is processed into three matrices:
#    - **K (Keys)**
#    - **Q (Queries)**
#    - **V (Values)**
#    (Each has the same shape: **C  HW**)
#
# 2 The **dot-product of Q and K** is computed to find the **channel-wise relationships**, producing an **attention map \(A_c\) (C  C matrix).**
#
# 3 The attention map is then **multiplied with V (Values)** to weight the most important feature channels.
#
# 4 The updated feature map is **reshaped back to C  H  W** and **added to the original input (\(E_i\))** to produce the final output \(E_o\).
#
#  **Key Benefit:**
# - Helps the network **identify the most meaningful feature channels** in hand images.
#
# ---
#
# ## ** (b) Spatial Attention Module with Relative Positional Encoding (SAM-RPE)**
#  **Purpose:**
# - Identifies **which regions (pixels) in the image are most important**.
# - Helps the model **understand spatial relationships** between different parts of the hand.
#
#  **How it Works:**
# 1 The input feature map \(E_i\) (**C  H  W**) is processed into:
#    - **K (Keys)**
#    - **Q (Queries)**
#    - **V (Values)**
#    (But here, Keys and Queries have smaller dimensions: **\(d_k \times HW\)**, where \(d_k = C/8\) to reduce computation.)
#
# 2 The **dot-product of Q and K** is computed to find the **spatial attention map \(A_s\) (HW  HW matrix).**
#
# 3 **Relative Positional Encoding (RPE) is applied** to fix a common problem in self-attention:
#    - The network **adds learned position embeddings** for height (\(P_H\)) and width (\(P_W\)), which helps maintain **spatial order** in the image.
#    - Without this, attention might treat different hand parts as interchangeable, leading to poor recognition.
#
# 4 The **final self-attended feature map** is obtained by combining:
#    - The **weighted values V**
#    - The **relative position-enhanced features from \(P_H\) and \(P_W\)**
#
# 5 The **output is normalized (BN: Batch Normalization)** and added back to the **original feature map** to get \(E_o\).
#
#  **Key Benefit:**
# - Helps the model **preserve the spatial structure of the hand** (e.g., keeping the correct positions of fingers and palm).
#
# ---
#
# ### ** Key Takeaways from the Figure**
#  **Channel Attention (CAM)**  Finds **which features are important**
#  **Spatial Attention (SAM-RPE)**  Finds **where the important features are**
#  **Relative Positional Encoding (RPE)** → Helps maintain **spatial consistency**
# ✔ **Final Output** → More **accurate hand-based person identification**
#
# ---

# %% [markdown]
# ## **Implementation of the Proposed System (MBA-Net)**
#
# ---
#
# ### **📌 Step 1: Understanding the Purpose of MBA-Net**
# - **Goal:** Identify individuals using **hand images** for biometric recognition, particularly for **criminal investigations**.
# - **Challenge:** Hand images have **background noise**, and important features (like finger structure, palm patterns) must be **highlighted** while ignoring irrelevant details.
# - **Solution:** **MBA-Net**, a deep learning model that **extracts hand features using attention mechanisms** while improving efficiency.
#
# ---
#
# ### **📌 Step 2: How MBA-Net Works**
# MBA-Net has three main components:
# 1️⃣ **Backbone Network (Feature Extractor) – ResNet50**
# 2️⃣ **Attention Modules – Channel & Spatial Attention**
# 3️⃣ **Final Classification for Identity Prediction**
#
# Each component is **trained end-to-end** to automatically learn important features from hand images.
#
# ---
#
# ### **🖥 Step 3: Implementation Details**
# #### **🔹 1. Backbone Network (Feature Extractor)**
# - Uses a **pretrained ResNet50** network as a starting point.
# - ResNet50 is a **deep convolutional neural network (CNN)** that processes hand images and extracts **basic feature maps**.
# - Only the **first three layers of ResNet50** remain unchanged.
# - After the third layer, the network **branches into three parts**.
#
# ---
#
# #### **🔹 2. Attention Mechanisms**
# MBA-Net **improves feature extraction** using two types of **attention mechanisms**:
#
# 1️⃣ **Channel Attention Module (CAM) – Identifies Important Feature Channels**
#    - **Purpose:** Focus on **which features are important** for hand recognition.
#    - **How it Works:**
#      - The network breaks down the **feature maps into separate channels**.
#      - It **assigns more importance** to channels that contain **relevant hand details**.
#      - Uses **dot-product attention** to calculate the relationship between channels.
#      - The model **learns to enhance important channels** while reducing the effect of less useful ones.
#
# 2️⃣ **Spatial Attention Module with Relative Positional Encoding (SAM-RPE) – Identifies Important Hand Regions**
#    - **Purpose:** Focus on **where in the image the most important information is**.
#    - **Problem with Normal Attention:** Traditional spatial attention does not consider **pixel positions**.
#    - **Solution:** **Relative Positional Encoding (RPE)**
#      - Adds extra information to **keep track of where each pixel is**.
#      - This prevents **loss of spatial relationships** when images are shifted or resized.
#
# ✅ **Benefit of Using Attention:**
# - Helps the model **filter out background noise**.
# - Focuses on **hand structure** while ignoring accessories, shadows, or unnecessary details.
#
# ---
#
# #### **🔹 3. Multi-Branch Design (Final Classification)**
# After passing through **attention modules**, the model **splits into three branches**:
# 1️⃣ **Channel Attention Branch (CAM output)**
# 2️⃣ **Spatial Attention Branch (SAM-RPE output)**
# 3️⃣ **Global Feature Branch (Normal ResNet50 Features, No Attention)**
#
# 📌 **Each branch processes the hand image separately** and produces **a 2048-dimensional feature vector**.
#
# - These vectors are then **combined into a single 6144-dimensional feature vector**.
# - Finally, a **fully connected (FC) layer with a softmax function** predicts the **identity of the person**.
#
# ---
#
# ### **📌 Step 4: Training the Model**
# #### **🔹 Datasets Used**
# 1️⃣ **11k Hands Dataset** – Contains **190 subjects**, divided into **four subsets** (left/right dorsal & palmar).
# 2️⃣ **HD Dataset** – Contains **502 subjects**, with **additional noisy images** for testing model robustness.
#
# #### **🔹 Training Process**
# 1️⃣ **Image Preprocessing:**
#    - Resize all images to **356×356** pixels.
#    - Apply **data augmentation** (random flipping, color jittering).
#    - Normalize the images.
#
# 2️⃣ **Optimization & Training Settings:**
#    - **Loss Function:** Cross-Entropy Loss
#    - **Optimizer:** Adam
#    - **Batch Size:** 20
#    - **Epochs:** 70
#    - **Weight Decay (Regularization):** 5 × 10⁻⁴
#    - **Learning Rate Schedule:**
#      - Starts small **(8 × 10⁻⁶)** and gradually increases over 10 epochs.
#      - **Reduces learning rate** after 40 & 60 epochs for stability.
#
# 3️⃣ **Testing Phase:**
#    - During testing, only **normalization is applied** (no cropping or flipping).
#    - The final **6144-dimensional feature vector** is used to compare test images against stored identities.
#
# ---
#
# ### **📌 Step 5: Evaluating Model Performance**
# #### **🔹 Metrics Used**
# - **Rank-1 Accuracy (%)** – Measures **how often the top prediction is correct**.
# - **mAP (%) (Mean Average Precision)** – Measures **how well the model retrieves relevant matches**.
#
# #### **🔹 Same-Domain Performance (Training & Testing on the Same Dataset)**
# | Method | Right Dorsal (11k) | Left Dorsal (11k) | Right Palmar (11k) | Left Palmar (11k) | HD Dataset |
# |--------|-----------------|----------------|-----------------|----------------|-------------|
# | **MBA-Net (Ours)** | **97.45% (mAP: 97.98%)** | **96.71% (mAP: 97.41%)** | **98.05% (mAP: 98.42%)** | **97.42% (mAP: 97.84%)** | **95.12% (mAP: 95.54%)** |
#
# ✅ **Key Finding:** MBA-Net **outperforms all existing methods**, achieving the highest accuracy.
#
# #### **🔹 Cross-Domain Performance (Training on One Dataset, Testing on Another)**
# | Method | 11k Hands → 11k Test | 11k Hands → HD Test |
# |--------|-----------------|----------------|
# | **MBA-Net (Ours)** | **97.45% (mAP: 97.98%)** | **84.41% (mAP: 85.98%)** |
#
# ✅ **Key Finding:** MBA-Net is **more generalizable** across datasets compared to other methods.
#
# ---
#
# ### **📌 Step 6: Key Findings from Ablation Study**
# The **Ablation Study** shows how each component improves performance.
#
# | Model Component | Rank-1 Accuracy (%) | mAP (%) |
# |----------------|----------------|----------------|
# | **Baseline ResNet50** (No Attention) | 95.43% | 95.95% |
# | **+ Spatial Attention** | 96.50% | 96.73% |
# | **+ Channel Attention** | 97.41% | 97.65% |
# | **+ Relative Positional Encoding (Final MBA-Net)** | **98.05%** | **98.42%** |
#
# ✅ **Key Insight:** Each module contributes to **better accuracy**, proving that attention mechanisms help improve hand-based identification.
#
# ---
#
# ### **📌 Step 7: Summary of the Implementation**
# 🚀 **Final Takeaways:**
# 1️⃣ **MBA-Net uses ResNet50** to extract features from hand images.
# 2️⃣ **Channel Attention & Spatial Attention (with Relative Positional Encoding) help focus on important features.**
# 3️⃣ **Three parallel branches improve accuracy by combining different feature representations.**
# 4️⃣ **Training on large hand datasets proves its effectiveness in biometric recognition.**
# 5️⃣ **MBA-Net significantly outperforms previous models, making it ideal for real-world applications.**
#
# ---
#
# ### **📌 Final Thoughts**
# MBA-Net is an effective **hand-based person recognition system** designed for **criminal investigations and biometric security**. By leveraging **multi-branch attention mechanisms**, the model achieves **state-of-the-art results**, proving that hand images can be a **reliable biometric modality**.
#
# ---

# %% [markdown]
# ## **🔮 Future Research Directions Based on MBA-Net**
#
# The MBA-Net model has **successfully improved hand-based person recognition** using attention mechanisms, but there are still areas where further research can enhance its **accuracy, generalizability, and efficiency**. Below are some possible future directions:
#
# ---
#
# ## **1️⃣ Expanding Hand-Based Biometric Recognition**
# 🔹 **Multi-Modal Hand Biometric Fusion**
# - Combine **hand images with other biometric data** such as **fingerprints, palm prints, or vein patterns** to improve identification accuracy.
# - Investigate whether **fusion of multiple hand biometrics** enhances performance.
#
# 🔹 **3D Hand Recognition**
# - Instead of using **2D images**, apply **3D hand reconstruction** techniques to improve robustness against hand pose variations.
# - Can leverage **depth sensors or stereo cameras** for better feature extraction.
#
# 🔹 **Cross-Modal Learning with Language and Vision**
# - Use **vision-language models** (like CLIP) to associate **hand images with textual descriptions** (e.g., hand scars, skin tone, unique marks).
# - Helps in forensic investigations where textual evidence exists but **no direct image dataset** is available.
#
# ---
#
# ## **2️⃣ Enhancing Attention Mechanisms**
# 🔹 **Adaptive Attention Mechanisms**
# - **Dynamically adjust attention weights** during inference based on input characteristics (e.g., skin texture, lighting conditions).
# - Can incorporate **reinforcement learning** to learn which attention weights work best for different hand types.
#
# 🔹 **Lightweight Attention for Real-Time Applications**
# - Implement **efficient self-attention mechanisms** (e.g., Linformer, Performer) to reduce computational cost.
# - This makes MBA-Net **suitable for deployment on edge devices** like smartphones or security cameras.
#
# ---
#
# ## **3️⃣ Generalization and Domain Adaptation**
# 🔹 **Few-Shot Learning for Hand-Based Recognition**
# - Train the model to **recognize new individuals with very few training images** (meta-learning).
# - Useful for forensic applications where **only one or two images of a suspect’s hand exist**.
#
# 🔹 **Cross-Domain Generalization**
# - Train and evaluate MBA-Net on **diverse hand datasets** across different skin tones, age groups, and lighting conditions.
# - Implement **domain adaptation techniques** to ensure MBA-Net works well in real-world settings without re-training.
#
# ---
#
# ## **4️⃣ Application in Forensic Investigations**
# 🔹 **Automated Hand Image Retrieval for Law Enforcement**
# - Develop a **hand-image search system** where investigators can upload a hand image and retrieve similar ones from criminal databases.
# - Can integrate **AI-powered suspect ranking** based on confidence scores.
#
# 🔹 **Real-Time Hand-Based Surveillance**
# - Adapt MBA-Net for **real-time video analysis**, where security cameras automatically detect and **track hands** for potential suspect identification.
# - Combine with **person re-identification (Re-ID)** to match **hands with full-body recognition models**.
#
# ---
#
# ## **5️⃣ Improving Training and Model Efficiency**
# 🔹 **Self-Supervised Learning for Hand Recognition**
# - Reduce dependency on labeled datasets by using **self-supervised learning techniques** like contrastive learning.
# - Helps train **models with minimal human supervision**.
#
# 🔹 **Knowledge Distillation for Lightweight Deployment**
# - Use **knowledge distillation** to train a **smaller, faster version of MBA-Net** while maintaining accuracy.
# - Enables deployment on **low-power devices like mobile phones, IoT cameras, and Raspberry Pi**.
#
# ---
#
# ## **6️⃣ Exploring Ethical Considerations**
# 🔹 **Bias and Fairness in Hand Recognition Models**
# - Investigate potential **biases in hand recognition across different ethnicities, genders, and age groups**.
# - Develop **bias-mitigation techniques** to ensure fair biometric identification.
#
# 🔹 **Privacy-Preserving Hand Recognition**
# - Implement **privacy-enhancing AI techniques** like federated learning or homomorphic encryption to **protect biometric data**.
# - Ensures that **hand biometrics remain secure** when used in law enforcement or personal authentication.
#
# ---
#
# ### **🚀 Final Thoughts**
# The **MBA-Net model** opens up many opportunities for advancing **hand-based person recognition**. Future research can focus on **making it more accurate, efficient, and applicable to real-world security and forensic applications**.
#
# Would you like a **detailed implementation roadmap** for any of these ideas? 🚀
